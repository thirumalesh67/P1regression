# %% [markdown]
# <a href="https://colab.research.google.com/github/lightsixer/P1regression/blob/dev/notebooks/House_Price_Prediction_using_XGBoost.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
from xgboost import XGBRegressor

# %%
path='../data/preptrain.csv'
data = pd.read_csv(path)
data.head()
# Out:
#    GrLivArea  LotArea  TotalBsmtSF  BsmtUnfSF  GarageArea  YearBuilt  \
# 0       1710     8450          856        150         548       2003
# 1       1262     9600         1262        284         460       1976
# 2       1786    11250          920        434         608       2001
# 3       1717     9550          756        540         642       1915
# 4       2198    14260         1145        490         836       2000
#
#    LotFrontage  YearRemodAdd  BsmtFinSF1  OpenPorchSF  SalePrice
# 0         65.0          2003         706           61     208500
# 1         80.0          1976         978            0     181500
# 2         68.0          2002         486           42     223500
# 3         60.0          1970         216           35     140000
# 4         84.0          2000         655           84     250000

# %%
X = data.drop('SalePrice',axis=1)
y = data['SalePrice']

X.head()
X.describe()
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   GrLivArea     1460 non-null   int64
#  1   LotArea       1460 non-null   int64
#  2   TotalBsmtSF   1460 non-null   int64
#  3   BsmtUnfSF     1460 non-null   int64
#  4   GarageArea    1460 non-null   int64
#  5   YearBuilt     1460 non-null   int64
#  6   LotFrontage   1460 non-null   float64
#  7   YearRemodAdd  1460 non-null   int64
#  8   BsmtFinSF1    1460 non-null   int64
#  9   OpenPorchSF   1460 non-null   int64
# dtypes: float64(1), int64(9)
# memory usage: 114.2 KB

# %%
X_train_full,X_valid_full,y_train,y_test = train_test_split(X,y,train_size=0.8,test_size=0.2,random_state=0)

# %%
categorical_col=[col for col in X_train_full.columns if X_train_full[col].dtype=='O' and X_train_full[col].nunique()<10]
print(categorical_col)

numerical_col=[col for col in X_train_full.columns if X_train_full[col].dtype in ['float64','int64']]
print(numerical_col)

my_cols=categorical_col + numerical_col
X_train = X_train_full[my_cols].copy()
X_valid = X_valid_full[my_cols].copy()
# Out:
# []
# ['GrLivArea', 'LotArea', 'TotalBsmtSF', 'BsmtUnfSF', 'GarageArea', 'YearBuilt', 'LotFrontage', 'YearRemodAdd', 'BsmtFinSF1', 'OpenPorchSF']

# %%
X_train.head()
# Out:
#      GrLivArea  LotArea  TotalBsmtSF  BsmtUnfSF  GarageArea  YearBuilt  \
# 618       1828    11694         1822       1774         774       2007
# 870        894     6600          894        894         308       1962
# 92         964    13360          876        163         432       1921
# 817       1689    13265         1568        350         857       2002
# 302       1541    13704         1541       1541         843       2001
#
#      LotFrontage  YearRemodAdd  BsmtFinSF1  OpenPorchSF
# 618    90.000000          2007          48          108
# 870    60.000000          1962           0            0
# 92     80.000000          2006         713            0
# 817    70.049958          2002        1218           59
# 302   118.000000          2002           0           81

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

numerical_transformer = SimpleImputer(strategy='mean')

categorical_transformer = Pipeline(steps=[
                                          ('impute',SimpleImputer(strategy='most_frequent')),
                                          ('onehot',OneHotEncoder(handle_unknown='ignore'))
])

preprocessor = ColumnTransformer(transformers=[
                                               ('num',numerical_transformer,numerical_col),
                                               ('cat',categorical_transformer,categorical_col)
])

# %%
my_model = XGBRegressor(n_estimators=1000, learning_rate=0.05, n_jobs=4)

# %%
eval_set_pipe = Pipeline(steps = [('preprocessor', preprocessor)])

X_train_eval=X_train.copy()
X_train_eval = eval_set_pipe.fit_transform(X_train)
pd.DataFrame(X_train_eval,index=X_train.index)
# Out:
#            0        1       2       3      4       5           6       7  \
# 618   1828.0  11694.0  1822.0  1774.0  774.0  2007.0   90.000000  2007.0
# 870    894.0   6600.0   894.0   894.0  308.0  1962.0   60.000000  1962.0
# 92     964.0  13360.0   876.0   163.0  432.0  1921.0   80.000000  2006.0
# 817   1689.0  13265.0  1568.0   350.0  857.0  2002.0   70.049958  2002.0
# 302   1541.0  13704.0  1541.0  1541.0  843.0  2001.0  118.000000  2002.0
# ...      ...      ...     ...     ...    ...     ...         ...     ...
# 763   2365.0   9430.0  1252.0    89.0  856.0  1999.0   82.000000  1999.0
# 835   1067.0   9600.0  1067.0   625.0  436.0  1950.0   60.000000  1995.0
# 1216  1902.0   8930.0     0.0     0.0  539.0  1978.0   68.000000  1978.0
# 559   1557.0   3196.0  1374.0  1374.0  420.0  2003.0   70.049958  2004.0
# 684   1839.0  16770.0  1195.0  1195.0  486.0  1998.0   58.000000  1998.0
#
#            8      9
# 618     48.0  108.0
# 870      0.0    0.0
# 92     713.0    0.0
# 817   1218.0   59.0
# 302      0.0   81.0
# ...      ...    ...
# 763   1163.0  128.0
# 835    442.0    0.0
# 1216     0.0    0.0
# 559      0.0   20.0
# 684      0.0   81.0
#
# [1168 rows x 10 columns]

# %%
# Make a copy to avoid changing original data
X_valid_eval=X_valid.copy()
# fit transform X_valid.copy()
X_valid_eval = eval_set_pipe.transform (X_valid_eval)

pd.DataFrame(X_valid_eval, index=X_valid.index)
# Out:
#            0        1       2      3      4       5           6       7  \
# 529   2515.0  32668.0  2035.0  816.0  484.0  1957.0   70.049958  1975.0
# 491   1578.0   9490.0   806.0  238.0  240.0  1941.0   79.000000  1950.0
# 459   1203.0   7015.0   709.0  524.0  352.0  1950.0   70.049958  1950.0
# 279   2022.0  10005.0  1160.0  768.0  505.0  1977.0   83.000000  1977.0
# 655   1092.0   1680.0   525.0  525.0  264.0  1971.0   21.000000  1971.0
# ...      ...      ...     ...    ...    ...     ...         ...     ...
# 326   1719.0  10846.0  1719.0  100.0  473.0  1993.0   32.000000  1993.0
# 440   2402.0  15431.0  3094.0  788.0  672.0  2008.0  105.000000  2008.0
# 1387  2526.0   8520.0   714.0    0.0  216.0  1916.0   60.000000  1950.0
# 1323   708.0   5330.0   420.0  140.0    0.0  1940.0   50.000000  1950.0
# 61    1111.0   7200.0   530.0  530.0  288.0  1920.0   60.000000  1996.0
#
#            8      9
# 529   1219.0    0.0
# 491    403.0    0.0
# 459    185.0    0.0
# 279    392.0  117.0
# 655      0.0    0.0
# ...      ...    ...
# 326   1619.0   30.0
# 440   1767.0   72.0
# 1387   168.0   15.0
# 1323   280.0    0.0
# 61       0.0    0.0
#
# [292 rows x 10 columns]

# %%
xgbm = my_model.fit(X_train_eval, y_train, early_stopping_rounds=20, eval_metric = "mae", eval_set=[(X_valid_eval, y_test)])
# Out:
# [0]	validation_0-mae:54604.70173
# [1]	validation_0-mae:52311.18343
# [2]	validation_0-mae:50185.52970
# [3]	validation_0-mae:48265.42246
# [4]	validation_0-mae:46366.05340
# [5]	validation_0-mae:44589.31694
# [6]	validation_0-mae:42920.42054
# [7]	validation_0-mae:41330.28382
# [8]	validation_0-mae:39811.88966
# [9]	validation_0-mae:38432.64785
# [10]	validation_0-mae:37108.29960
# [11]	validation_0-mae:35754.85119
# [12]	validation_0-mae:34487.85408
# [13]	validation_0-mae:33376.06218
# [14]	validation_0-mae:32392.66238
# [15]	validation_0-mae:31525.74371
# [16]	validation_0-mae:30657.49064
# [17]	validation_0-mae:29876.68292
# [18]	validation_0-mae:29189.02411
# [19]	validation_0-mae:28518.51881
# [20]	validation_0-mae:27885.54155
# [21]	validation_0-mae:27241.96158
# [22]	validation_0-mae:26652.48411
# [23]	validation_0-mae:26123.92621
# [24]	validation_0-mae:25627.55407
# [25]	validation_0-mae:25221.21530
# [26]	validation_0-mae:24800.44250
# [27]	validation_0-mae:24433.48063
# [28]	validation_0-mae:24115.97367
# [29]	validation_0-mae:23845.52857
# [30]	validation_0-mae:23589.19900
# [31]	validation_0-mae:23321.60614
# [32]	validation_0-mae:23028.60496
# [33]	validation_0-mae:22785.29915
# [34]	validation_0-mae:22588.65296
# [35]	validation_0-mae:22423.18482
# [36]	validation_0-mae:22254.95647
# [37]	validation_0-mae:22077.84964
# [38]	validation_0-mae:22017.06865
# [39]	validation_0-mae:21883.54621
# [40]	validation_0-mae:21774.35994
# [41]	validation_0-mae:21656.37163
# [42]	validation_0-mae:21579.45882
# [43]	validation_0-mae:21533.26402
# [44]	validation_0-mae:21482.80921
# [45]	validation_0-mae:21430.37974
# [46]	validation_0-mae:21350.51365
# [47]	validation_0-mae:21313.22940
# [48]	validation_0-mae:21268.02065
# [49]	validation_0-mae:21209.27266
# [50]	validation_0-mae:21159.31089
# [51]	validation_0-mae:21118.33570
# [52]	validation_0-mae:21105.73381
# [53]	validation_0-mae:21085.56148
# [54]	validation_0-mae:21046.27614
# [55]	validation_0-mae:21022.23721
# [56]	validation_0-mae:21005.91024
# [57]	validation_0-mae:20964.24045
# [58]	validation_0-mae:20936.06370
# [59]	validation_0-mae:20891.68231
# [60]	validation_0-mae:20844.00503
# [61]	validation_0-mae:20813.82970
# [62]	validation_0-mae:20782.73809
# [63]	validation_0-mae:20760.23962
# [64]	validation_0-mae:20751.52419
# [65]	validation_0-mae:20722.62390
# [66]	validation_0-mae:20708.24526
# [67]	validation_0-mae:20679.11178
# [68]	validation_0-mae:20660.90689
# [69]	validation_0-mae:20666.72244
# [70]	validation_0-mae:20653.26084
# [71]	validation_0-mae:20648.70374
# [72]	validation_0-mae:20622.17621
# [73]	validation_0-mae:20604.78136
# [74]	validation_0-mae:20580.28477
# [75]	validation_0-mae:20578.18725
# [76]	validation_0-mae:20570.48417
# [77]	validation_0-mae:20552.99860
# [78]	validation_0-mae:20548.10057
# [79]	validation_0-mae:20548.58944
# [80]	validation_0-mae:20547.81053
# [81]	validation_0-mae:20538.45544
# [82]	validation_0-mae:20532.61716
# [83]	validation_0-mae:20539.24861
# [84]	validation_0-mae:20538.98880
# [85]	validation_0-mae:20529.10195
# [86]	validation_0-mae:20526.40262
# [87]	validation_0-mae:20518.40460
# [88]	validation_0-mae:20523.00219
# [89]	validation_0-mae:20518.61972
# [90]	validation_0-mae:20523.86510
# [91]	validation_0-mae:20530.21151
# [92]	validation_0-mae:20526.38779
# [93]	validation_0-mae:20525.54670
# [94]	validation_0-mae:20532.65711
# [95]	validation_0-mae:20531.83089
# [96]	validation_0-mae:20541.24280
# [97]	validation_0-mae:20534.75819
# [98]	validation_0-mae:20512.30085
# [99]	validation_0-mae:20523.51975
# [100]	validation_0-mae:20529.12881
# [101]	validation_0-mae:20526.16782
# [102]	validation_0-mae:20517.68276
# [103]	validation_0-mae:20498.52053
# [104]	validation_0-mae:20489.69232
# [105]	validation_0-mae:20495.95369
# [106]	validation_0-mae:20489.60634
# [107]	validation_0-mae:20499.92613
# [108]	validation_0-mae:20511.37665
# [109]	validation_0-mae:20492.82132
# [110]	validation_0-mae:20493.93125
# [111]	validation_0-mae:20477.04154
# [112]	validation_0-mae:20469.77801
# [113]	validation_0-mae:20453.80601
# [114]	validation_0-mae:20461.89396
# [115]	validation_0-mae:20473.65153
# [116]	validation_0-mae:20485.99081
# [117]	validation_0-mae:20486.15957
# [118]	validation_0-mae:20482.03029
# [119]	validation_0-mae:20477.55846
# [120]	validation_0-mae:20464.56451
# [121]	validation_0-mae:20465.60350
# [122]	validation_0-mae:20470.11228
# [123]	validation_0-mae:20466.27082
# [124]	validation_0-mae:20466.57157
# [125]	validation_0-mae:20470.72005
# [126]	validation_0-mae:20459.27127
# [127]	validation_0-mae:20453.83690
# [128]	validation_0-mae:20458.31338
# [129]	validation_0-mae:20461.07042
# [130]	validation_0-mae:20468.27463
# [131]	validation_0-mae:20475.02381
# [132]	validation_0-mae:20480.11832
# [133]	validation_0-mae:20478.81287

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import accuracy_score
preds = my_model.predict(X_valid_eval)

# Evaluate the model
score = mean_absolute_error(y_test, preds)
print('MAE:', score)
# Out:
# MAE: 20453.806011879282

# %%
from xgboost.sklearn import xgboost_model_doc
import pickle
import os
pickle.dump(xgbm, open(os.path.join( '../models/','xgboost.pkl'), 'wb'),protocol=4)
