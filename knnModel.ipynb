# %% [markdown]
# <a href="https://colab.research.google.com/github/lightsixer/P1regression/blob/dev/knnModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sklearn
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import f1_score
import pandas as pd

data = pd.read_csv('preptrain.csv')
test_data =pd.read_csv('preptest.csv')
data.head()
# Out:
#    GrLivArea  LotArea  TotalBsmtSF  BsmtUnfSF  GarageArea  YearBuilt  \
# 0       1710     8450          856        150         548       2003
# 1       1262     9600         1262        284         460       1976
# 2       1786    11250          920        434         608       2001
# 3       1717     9550          756        540         642       1915
# 4       2198    14260         1145        490         836       2000
#
#    LotFrontage  YearRemodAdd  BsmtFinSF1  OpenPorchSF  SalePrice
# 0         65.0          2003         706           61     208500
# 1         80.0          1976         978            0     181500
# 2         68.0          2002         486           42     223500
# 3         60.0          1970         216           35     140000
# 4         84.0          2000         655           84     250000

# %%
#X = data.iloc[:, :-1]
#y = data.iloc[:, -1]

X = data.drop('SalePrice', axis = 1)
y = data.SalePrice
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=841, shuffle = True)

kRegression = KNeighborsRegressor(n_neighbors = 5)
kRegression.fit(X_train, y_train)

trainR = kRegression.predict(X_train)

testR = kRegression.predict(X_test)


pred = kRegression.predict(X_train)
train_r2 = r2_score(y_train, pred)

pred = kRegression.predict(X_test)
test_r2 = r2_score(y_test,pred)

print("The r2 score for the training set is : ", train_r2)
print("The r2 score for the testing set is : ", test_r2)

#f1s = f1_score(y_test, pred)
#score = trainR.score(X_train, y_train)
#acc = accuracy_score(y_test, pred)
#print(acc)


#mse = mean_squared_error(y_test, pred)
#r2_KNRtrain(trainR, y_train)

#accuracy_score(test_data,y_test)

#r2_KNRtrain=f1_score(y_train, trainR)

#print(r2_KNRtrain)
#acctrain = accuracy_score(y_train, trainR)
#acctest = accuracy_score(y_test, testR)
#prediction = kRegression.predict(X_test)

#accuracy = accuracy_score(test_data, prediction)
# Out:
# The r2 score for the training set is :  0.7742906162968173
# The r2 score for the testing set is :  0.672338009008848

# %%
#X = data.iloc[:, :-1] #gets the data except the last column
#y = data.iloc[:, -1] #gets the last column

#X = data

#y = data

#y = data['SalePrice']
#data.drop('SalePrice', inplace = True, axis = 1)

X = data

print(X.shape)
print(y.shape)

def KNeighborsRegressorModel(X_train,X_test , y_train , y_test):
    KNRmodel = KNeighborsRegressor()
    KNRmodel.fit(X_train , y_train)
    TrainKNRpredmodel = KNRmodel.predict(X_train)
    TestKNRpredmodel = KNRmodel.predict(X_test)
    r2_KNRtrain=r2_score(y_train, TrainKNRpredmodel)
    r2_KNRtest = r2_score(y_test, TestKNRpredmodel)
    mean_squared_error_train = mean_squared_error(y_train , TrainKNRpredmodel)
    mean_squared_error_test = mean_squared_error(y_test , TestKNRpredmodel)
    print(f"r2_score KNR train: {r2_KNRtrain}")
    print(f"r2_score KNR test: {r2_KNRtest}")
    print(f"mean_squared_error_train : {mean_squared_error_train}")
    print(f"mean_squared_error_test : {mean_squared_error_test}")
    return KNRmodel
print("---------------")
KNRModel = KNeighborsRegressorModel(X_train,X_test , y_train , y_test)
KNRtestPred = KNRModel.predict(test_data)

#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=841, shuffle = True)

#kRegression = KNeighborsRegressor(n_neighbors = 5)
#kRegression.fit(X_train, y_train)

#prediction = kRegression.predict(X_test)

#x = f1_score(y_test, prediction)
#accuracy = accuracy_score(y_test, prediction)

#print(accuracy)
# Out:
# (1460, 11)
# (1460,)
# ---------------
# r2_score KNR train: 0.7742906162968173
# r2_score KNR test: 0.672338009008848
# mean_squared_error_train : 1395109776.1333334
# mean_squared_error_test : 2186656059.5438905
